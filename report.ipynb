# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import sympy as sp

# %%
# Uniform
precisions = [0.6,0.6,0.6,0.6,0.6,0.6]
recalls = [0.59,0.58,0.59,0.59,0.59,0.59]
f1s = [0.6,0.59,0.59,0.6,0.6,0.59]
samples = [10,20,30,40,50,60]
frames = [39,52,46,42,37,38]
plt.plot(samples, frames, label="Frames needed to re-detect")
plt.xlabel("number of randomly sampled regions")
plt.ylabel("number of frames")
plt.legend()

# %%
# Gauss fixed
frames = 34
precision = 0.60
recall = 0.59
f1 = 0.6
# Gauss growing
frames = 36
precision = 0.60
recall = 0.59
f1 = 0.6

# %%
# Testing threshold
ths = [0.5,1,1.5,2,2.5,3,3.5,4,4.5,5]
precisions = [0.64,0.64,0.64,0.6,0.6,0.6,0.6,0.6,0.6,0.6]
recalls = [0.27,0.27,0.27,0.59,0.59,0.59,0.59,0.59,0.59,0.57]
f1s = [0.38,0.38,0.38,0.59,0.6,0.6,0.6,0.6,0.6,0.58]
frames = [23,32,32,36,39,54,144]
plt.plot(ths, precisions, label="Precision")
plt.plot(ths, recalls, label="Recall")
plt.plot(ths, f1s, label="F1-score")
plt.xlabel("threshold value")
plt.ylabel("results")
plt.ylim(0, 1)
plt.legend()
